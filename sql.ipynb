# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# 1. Membuat SparkSession
spark = SparkSession.builder \
    .appName("Contoh PySpark Sederhana") \
    .getOrCreate()

# 2. Membuat DataFrame dari data list
data = [
    ("Andi", 25),
    ("Budi", 30),
    ("Citra", 22),
    ("Dina", 28)
]

columns = ["Nama", "Umur"]

df = spark.createDataFrame(data, columns)

# 3. Menampilkan isi DataFrame
print("Data Awal:")
df.show()
# Out:
# 25/05/14 09:46:57 WARN Utils: Your hostname, lindaanggara-VMware-Virtual-Platform resolves to a loopback address: 127.0.1.1; using 192.168.30.129 instead (on interface ens33)
# 25/05/14 09:46:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/14 09:46:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Data Awal:
# +-----+----+
# | Nama|Umur|
# +-----+----+
# | Andi|  25|
# | Budi|  30|
# |Citra|  22|
# | Dina|  28|
# +-----+----+
# 25/05/14 09:47:12 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# 1. Membuat SparkSession
spark = SparkSession.builder \
    .appName("Contoh PySpark Sederhana") \
    .getOrCreate()

# 2. Membuat DataFrame dari data list
data = [
    ("Andi", 25),
    ("Budi", 30),
    ("Citra", 22),
    ("Dina", 28)
]

columns = ["Nama", "Umur"]

df = spark.createDataFrame(data, columns)

# 3. Menampilkan isi DataFrame
print("Data Awal:")
df.show()

# 4. Filter data (misalnya umur > 25)
df_filtered = df.filter(col("Umur") > 25)

print("Data setelah filter umur > 25:")
df_filtered.show()

# 5. Menutup SparkSession
spark.stop()
# Out:
# Data Awal:
# +-----+----+
# | Nama|Umur|
# +-----+----+
# | Andi|  25|
# | Budi|  30|
# |Citra|  22|
# | Dina|  28|
# +-----+----+
#
# Data setelah filter umur > 25:
# +----+----+
# |Nama|Umur|
# +----+----+
# |Budi|  30|
# |Dina|  28|
# +----+----+
